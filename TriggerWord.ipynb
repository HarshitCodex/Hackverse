# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\Hackverse'

# %%
import numpy as np
from pydub import AudioSegment
import random
import sys
import io
import os
import glob
import IPython
import td_utils
# %matplotlib inline

# %%
x = graph_spectrogram("recording.wav")

# %%
_, data = wavfile.read("recording.wav")
print("Time steps in audio recording before spectrogram", data[:,0].shape)
print("Time steps in input after spectrogram", x.shape)
# Out:
# Time steps in audio recording before spectrogram (363520,)
# Time steps in input after spectrogram (101, 4542)
